# %%
from google.colab import drive
from os.path import join
drive.mount('/gdrive')
gdrive_root = '/gdrive/My Drive'
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %% [markdown]
# # **Git synchronizing**
#
# If you finish your work, please run the following code to update the git repository.

# %%
PROJECT_PATH = join(gdrive_root, "CAMP---Context-Aware-Mining-Patterns-for-Interaction-Failures")
GIT_USERNAME = "KAIST-SE-LAB"
GIT_TOKEN = "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"
GIT_REPO = "CAMP---Context-Aware-Mining-Patterns-for-Interaction-Failures"

#print(PROJECT_PATH)

GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPO + ".git"
#print("GIT_PATH: ", GIT_PATH)

#%cd "{gdrive_root}"
#!git clone "{GIT_PATH}"

# %cd "{PROJECT_PATH}"
# !git config --global user.email "abalon1210@daum.net"           # Your Gite-mail
# !git config --global user.name "abalon1210"                     # Your Github ID

#!git add .
#!git commit -m "add sample logs" # Add your commit message here
# !git push origin main
# Out:
# /gdrive/My Drive/CAMP---Context-Aware-Mining-Patterns-for-Interaction-Failures
# Counting objects: 282, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (282/282), done.
# Writing objects: 100% (282/282), 35.57 MiB | 1.43 MiB/s, done.
# Total 282 (delta 272), reused 0 (delta 0)
# remote: Resolving deltas: 100% (272/272), done.
# remote: This repository moved. Please use the new location:
# remote:   https://github.com/KAIST-SE-Lab/CAMP---Context-Aware-Mining-Patterns-for-Interaction-Failures.git
# To https://github.com/KAIST-SE-LAB/CAMP---Context-Aware-Mining-Patterns-for-Interaction-Failures.git
#    5eae0e0..75bd7c2  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
