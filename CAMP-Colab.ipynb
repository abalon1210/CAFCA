# %% [markdown]
# # **Colab Initialization**

# %%
from google.colab import drive
from os.path import join
drive.mount('/gdrive')
gdrive_root = '/gdrive/My Drive'
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %% [markdown]
# # **Model Abstraction**

# %% [markdown]
# ## Log Parser

# %% [markdown]
# ## Model generator

# %% [markdown]
# # **Clustering for Initial Pattern Mining**

# %% [markdown]
# ## State & Message identity checker

# %% [markdown]
# ## Clustering

# %% [markdown]
# # **Extended SBFL for Pattern Elaboration**

# %% [markdown]
# ## SBFL Executor

# %% [markdown]
# # **Evaluation**

# %% [markdown]
# # **Git synchronizing**
#
# If you finish your work, please run the following code to update the git repository.

# %%
PROJECT_PATH = join(gdrive_root, "CAMP---Context-Aware-Mining-Patterns-for-Interaction-Failures")
GIT_USERNAME = "abalon1210"
GIT_TOKEN = "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"
GIT_REPO = "CAMP---Context-Aware-Mining-Patterns-for-Interaction-Failures"

#print(PROJECT_PATH)

GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPO + ".git"
#print("GIT_PATH: ", GIT_PATH)

# %cd "{PROJECT_PATH}"
# !git config --global user.email "abalon1210@daum.net"           # Your Github e-mail
# !git config --global user.name "abalon1210"                     # Your Github ID

# !git add .
# !git commit -m "Colab Initialization"                           # Add your commit message here
#!git remote rm origin
#!git remote add origin "{GIT_PATH}"
# !git remote -v
# !git push origin main
# Out:
# /gdrive/My Drive/CAMP---Context-Aware-Mining-Patterns-for-Interaction-Failures
# [main 3bec5a7] Colab Initialization
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite CAMP-Colab.ipynb (96%)
# origin	https://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@github.com/abalon1210/CAMP---Context-Aware-Mining-Patterns-for-Interaction-Failures.git (fetch)
# origin	https://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@github.com/abalon1210/CAMP---Context-Aware-Mining-Patterns-for-Interaction-Failures.git (push)
# fatal: could not read Password for 'https://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@github.com': No such device or address
