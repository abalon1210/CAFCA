# %% [markdown]
# # **Colab Initialization**

# %%
from google.colab import drive
from os.path import join
drive.mount('/gdrive')
gdrive_root = '/gdrive/My Drive'
# Out:
# Mounted at /gdrive

# %% [markdown]
# # **Interaction Model Abstraction**
#
# Abstract the observable environmental sensing data & communication traces from the logs

# %% [markdown]
# ## Log Parser

# %%
import os

LOG_PATH = join(gdrive_root, 'CAMP---Context-Aware-Mining-Patterns-for-Interaction-Failures/SampleLogs_OP_SUCCESS_RATE')
print('In Log Folder : ', os.listdir(LOG_PATH))
# Out:
# In Log Folder :  ['671_0plnData.txt', '671_0plnConfig.txt', '671_0vehicleData.txt', '671_0emissionData.txt', '681_0emissionData.txt', '681_0plnConfig.txt', '681_0plnData.txt', '681_0vehicleData.txt', '691_0emissionData.txt', '691_0plnConfig.txt', '691_0plnData.txt', '691_0vehicleData.txt', '701_0vehicleData.txt', '701_0plnConfig.txt', '701_0plnData.txt', '700_0emissionData.txt', '712_0plnData.txt', '712_0plnConfig.txt', '711_0emissionData.txt', '712_0vehicleData.txt', '719_0plnConfig.txt', '720_0vehicleData.txt', '719_0emissionData.txt', '720_0plnData.txt', '730_0vehicleData.txt', '729_0plnConfig.txt', '729_0emissionData.txt', '730_0plnData.txt', '672_0plnConfig.txt', '672_0emissionData.txt', '672_0vehicleData.txt', '672_0plnData.txt', '673_0plnData.txt', '673_0plnConfig.txt', '673_0vehicleData.txt', '673_0emissionData.txt', '674_0plnConfig.txt', '674_0vehicleData.txt', '674_0plnData.txt', '674_0emissionData.txt', '675_0plnData.txt', '675_0emissionData.txt', '675_0vehicleData.txt', '675_0plnConfig.txt', '676_0plnConfig.txt', '676_0vehicleData.txt', '676_0emissionData.txt', '676_0plnData.txt', '677_0vehicleData.txt', '677_0emissionData.txt', '677_0plnConfig.txt', '677_0plnData.txt', '678_0plnData.txt', '678_0plnConfig.txt', '678_0vehicleData.txt', '678_0emissionData.txt', '679_0vehicleData.txt', '679_0plnConfig.txt', '679_0emissionData.txt', '679_0plnData.txt', '680_0plnData.txt', '680_0emissionData.txt', '680_0plnConfig.txt', '680_0vehicleData.txt', '682_0emissionData.txt', '682_0plnConfig.txt', '682_0vehicleData.txt', '682_0plnData.txt', '683_0emissionData.txt', '683_0plnConfig.txt', '683_0vehicleData.txt', '683_0plnData.txt', '684_0plnConfig.txt', '684_0plnData.txt', '684_0emissionData.txt', '684_0vehicleData.txt', '685_0vehicleData.txt', '685_0plnConfig.txt', '685_0plnData.txt', '685_0emissionData.txt', '686_0plnConfig.txt', '686_0vehicleData.txt', '686_0plnData.txt', '686_0emissionData.txt', '687_0vehicleData.txt', '687_0plnData.txt', '687_0plnConfig.txt', '687_0emissionData.txt', '688_0vehicleData.txt', '688_0plnData.txt', '688_0emissionData.txt', '688_0plnConfig.txt', '689_0plnData.txt', '689_0vehicleData.txt', '689_0emissionData.txt', '689_0plnConfig.txt', '690_0vehicleData.txt', '690_0plnData.txt', '690_0emissionData.txt', '690_0plnConfig.txt', '692_0plnData.txt', '692_0vehicleData.txt', '692_0emissionData.txt', '692_0plnConfig.txt', '693_0plnConfig.txt', '693_0emissionData.txt', '693_0vehicleData.txt', '693_0plnData.txt', '694_0emissionData.txt', '694_0plnData.txt', '694_0plnConfig.txt', '694_0vehicleData.txt', '695_0plnConfig.txt', '695_0vehicleData.txt', '695_0emissionData.txt', '695_0plnData.txt', '696_0vehicleData.txt', '696_0plnConfig.txt', '697_0plnData.txt', '697_0vehicleData.txt', '697_0plnConfig.txt', '696_0emissionData.txt', '698_0plnConfig.txt', '698_0plnData.txt', '697_0emissionData.txt', '698_0vehicleData.txt', '699_0plnData.txt', '699_0plnConfig.txt', '699_0vehicleData.txt', '698_0emissionData.txt', '700_0plnConfig.txt', '700_0plnData.txt', '699_0emissionData.txt', '700_0vehicleData.txt', '701_0emissionData.txt', '702_0plnConfig.txt', '702_0vehicleData.txt', '702_0plnData.txt', '703_0plnData.txt', '702_0emissionData.txt', '703_0vehicleData.txt', '703_0plnConfig.txt', '704_0vehicleData.txt', '704_0plnData.txt', '704_0plnConfig.txt', '703_0emissionData.txt', '705_0plnConfig.txt', '704_0emissionData.txt', '705_0vehicleData.txt', '705_0plnData.txt', '706_0vehicleData.txt', '706_0plnData.txt', '706_0plnConfig.txt', '705_0emissionData.txt', '707_0plnData.txt', '707_0vehicleData.txt', '706_0emissionData.txt', '707_0plnConfig.txt', '708_0plnConfig.txt', '708_0plnData.txt', '707_0emissionData.txt', '708_0vehicleData.txt', '709_0plnConfig.txt', '709_0vehicleData.txt', '708_0emissionData.txt', '709_0plnData.txt', '710_0plnData.txt', '710_0plnConfig.txt', '709_0emissionData.txt', '710_0vehicleData.txt', '711_0vehicleData.txt', '710_0emissionData.txt', '711_0plnConfig.txt', '711_0plnData.txt', '713_0plnConfig.txt', ' ...

# %% [markdown]
# ## Interaction model generator

# %% [markdown]
# # **Clustering for Initial Pattern Mining**
#
# Generate initial subsequential patterns by clustering based on the failed logs
# Overlapping clustering approach is applied.

# %% [markdown]
# ## Environmental state & message identity checker

# %% [markdown]
# ###LCS Algorithm

# %%
def LCSExtractor(pattern, input, d_threshold):
  len_ptn = len(pattern)
  len_input = len(input)
  LCS = [[0]*(len_input+1) for i in range(len_ptn+1)]
  prev_i = -1
  prev_j = -1

  # Generate the LCS table of the interaction models
  for i in range(len_ptn+1):
    for j in range(len_input+1):
      if MCT(pattern[i-1], input[j-1]) == True:
        if (prev_i == -1 and prev_j == -1) or (calMessageDelay(pattern, input, prev_i, prev_j) <= d_threshold):
          LCS[i][j] = LCS[i-1][j-1] + 1
          if prev_i != i:
            prev_i = i
            prev_j = j
        else:
          LCS[i][j] = max(LCS[i][j-1], LCS[i-1][j])
      else:
        LCS[i][j] = max(LCS[i][j-1], LCS[i-1][j])
  
  # Extract the LCS from the table
  ret = []
  if LCS[len_ptn][len_input] == 0: return None
  else:
    current = 0
    for i in range(1,len_ptn+1):
      for j in range(1, len_input+1):
        if LCS[i][j] > current:
          current += 1
          if pattern[i-1].time >= 25.0: ret.append(pattern[i-1])  # TODO should be modified by model
    return ret

# %% [markdown]
# ## Clustering

# %% [markdown]
# # **Extended SBFL for Pattern Elaboration**
#
# Extend SBFL approach to make the patterns more elaborative using failed & passed logs

# %% [markdown]
# ## SBFL Executor

# %% [markdown]
# # **Evaluation**

# %% [markdown]
# # **Git synchronizing**
#
# If you finish your work, please run the following code to update the git repository.

# %%
PROJECT_PATH = join(gdrive_root, 'CAMP---Context-Aware-Mining-Patterns-for-Interaction-Failures')
GIT_USERNAME = 'abalon1210'
GIT_TOKEN = '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'
GIT_REPO = 'CAMP---Context-Aware-Mining-Patterns-for-Interaction-Failures'

#print(PROJECT_PATH)

GIT_PATH = 'https://' + GIT_TOKEN + '@github.com/' + GIT_USERNAME + '/' + GIT_REPO + '.git'
#print("GIT_PATH: ", GIT_PATH)

# %cd '{PROJECT_PATH}'
# !git config --global user.email 'abalon1210@daum.net'           # Your Github e-mail
# !git config --global user.name 'abalon1210'                     # Your Github ID

# !git reset
# !git add 'CAMP-Colab.ipynb'
# !git commit -m 'Implement Initial LCS algorithm for interaction model'                           # Add your commit message here
# !git remote rm origin
# !git remote add origin "{GIT_PATH}"
# !git remote -v
# !git push origin main
# Out:
# /gdrive/My Drive/CAMP---Context-Aware-Mining-Patterns-for-Interaction-Failures
# Unstaged changes after reset:
# M	CAMP-Colab.ipynb
